# %% [markdown]
# # Theory and Practice of Visualization Exercise 2

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Violations of graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *negative* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [CNN](http://www.cnn.com/)
# * [Fox News](http://www.foxnews.com/)
# * [Time](http://time.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
# Add your filename and uncomment the following line:
Image(filename='cnn-gallup-20050322.jpg')

# %% [markdown]
# Describe in detail the ways in which the visualization violates graphical *integrity* and *excellence*:

# %% [markdown]
# First of all, the graph is very deceiving. By having the lowest y value start at 53 instead of 0 makes it seem that Democrats agree several times more than the Republicans and Independents, when in actuality they only agree 8% more of the time. Another aspect of this visualization I don't like is that they didn't label their y-axis. The y-axis could indicate number of people, percentage of people, number of bunnies, etc. The question that tries to describe what the graph means does a very poor job. I have no idea what case they are referring to or who has the feeding tube and why.
